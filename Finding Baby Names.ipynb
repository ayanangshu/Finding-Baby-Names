# %%
import numpy as np
import matplotlib.pyplot as pp
import pandas as pd
import seaborn

# %%
# %matplotlib inline

# %%
import os
os.listdir('names')
# Out:
# ['NationalReadMe.pdf',
#  'yob1880.txt',
#  'yob1881.txt',
#  'yob1882.txt',
#  'yob1883.txt',
#  'yob1884.txt',
#  'yob1885.txt',
#  'yob1886.txt',
#  'yob1887.txt',
#  'yob1888.txt',
#  'yob1889.txt',
#  'yob1890.txt',
#  'yob1891.txt',
#  'yob1892.txt',
#  'yob1893.txt',
#  'yob1894.txt',
#  'yob1895.txt',
#  'yob1896.txt',
#  'yob1897.txt',
#  'yob1898.txt',
#  'yob1899.txt',
#  'yob1900.txt',
#  'yob1901.txt',
#  'yob1902.txt',
#  'yob1903.txt',
#  'yob1904.txt',
#  'yob1905.txt',
#  'yob1906.txt',
#  'yob1907.txt',
#  'yob1908.txt',
#  'yob1909.txt',
#  'yob1910.txt',
#  'yob1911.txt',
#  'yob1912.txt',
#  'yob1913.txt',
#  'yob1914.txt',
#  'yob1915.txt',
#  'yob1916.txt',
#  'yob1917.txt',
#  'yob1918.txt',
#  'yob1919.txt',
#  'yob1920.txt',
#  'yob1921.txt',
#  'yob1922.txt',
#  'yob1923.txt',
#  'yob1924.txt',
#  'yob1925.txt',
#  'yob1926.txt',
#  'yob1927.txt',
#  'yob1928.txt',
#  'yob1929.txt',
#  'yob1930.txt',
#  'yob1931.txt',
#  'yob1932.txt',
#  'yob1933.txt',
#  'yob1934.txt',
#  'yob1935.txt',
#  'yob1936.txt',
#  'yob1937.txt',
#  'yob1938.txt',
#  'yob1939.txt',
#  'yob1940.txt',
#  'yob1941.txt',
#  'yob1942.txt',
#  'yob1943.txt',
#  'yob1944.txt',
#  'yob1945.txt',
#  'yob1946.txt',
#  'yob1947.txt',
#  'yob1948.txt',
#  'yob1949.txt',
#  'yob1950.txt',
#  'yob1951.txt',
#  'yob1952.txt',
#  'yob1953.txt',
#  'yob1954.txt',
#  'yob1955.txt',
#  'yob1956.txt',
#  'yob1957.txt',
#  'yob1958.txt',
#  'yob1959.txt',
#  'yob1960.txt',
#  'yob1961.txt',
#  'yob1962.txt',
#  'yob1963.txt',
#  'yob1964.txt',
#  'yob1965.txt',
#  'yob1966.txt',
#  'yob1967.txt',
#  'yob1968.txt',
#  'yob1969.txt',
#  'yob1970.txt',
#  'yob1971.txt',
#  'yob1972.txt',
#  'yob1973.txt',
#  'yob1974.txt',
#  'yob1975.txt',
#  'yob1976.txt',
#  'yob1977.txt',
#  'yob1978.txt',
#  'yob1979.txt',
#  'yob1980.txt',
#  'yob1981.txt',
#  'yob1982.txt',
#  'yob1983.txt',
#  'yob1984.txt',
#  'yob1985.txt',
#  'yob1986.txt',
#  'yob1987.txt',
#  'yob1988.txt',
#  'yob1989.txt',
#  'yob1990.txt',
#  'yob1991.txt',
#  'yob1992.txt',
#  'yob1993.txt',
#  'yob1994.txt',
#  'yob1995.txt',
#  'yob1996.txt',
#  'yob1997.txt',
#  'yob1998.txt',
#  'yob1999.txt',
#  'yob2000.txt',
#  'yob2001.txt',
#  'yob2002.txt',
#  'yob2003.txt',
#  'yob2004.txt',
#  'yob2005.txt',
#  'yob2006.txt',
#  'yob2007.txt',
#  'yob2008.txt',
#  'yob2009.txt',
#  'yob2010.txt']

# %%
open('names/yob2010.txt','r').readlines()[:10]
# Out:
# ['Isabella,F,22731\n',
#  'Sophia,F,20477\n',
#  'Emma,F,17179\n',
#  'Olivia,F,16860\n',
#  'Ava,F,15300\n',
#  'Emily,F,14172\n',
#  'Abigail,F,14124\n',
#  'Madison,F,13070\n',
#  'Chloe,F,11656\n',
#  'Mia,F,10541\n']

# %%
names2011=pd.read_csv('names/yob2010.txt')

# %%
names2011.head()
# Out:
#                                                 name  sex number
# 0                                    <!DOCTYPE html>  NaN    NaN
# 1                                   <html lang="en">  NaN    NaN
# 2                                             <head>  NaN    NaN
# 3                             <meta charset="utf-8">  NaN    NaN
# 4    <link crossorigin="anonymous" href="https://...  NaN    NaN

# %%
names2011=pd.read_csv('names/yob2010.txt',names=['name','sex','number'])

# %%
names2011.head()
# Out:
#        name sex  number
# 0  Isabella   F   22731
# 1    Sophia   F   20477
# 2      Emma   F   17179
# 3    Olivia   F   16860
# 4       Ava   F   15300

# %%
names_all_list=[]

for year in range(1880,2009+1):
    names_all_list.append(pd.read_csv('names/yob{}.txt'.format(year),names=['name','sex','number']))
    names_all_list[-1]['year']=year
    
allyears=pd.concat(names_all_list)

# %%
allyears.head()
# Out:
#         name sex  number  year
# 0       Mary   F    7065  1880
# 1       Anna   F    2604  1880
# 2       Emma   F    2003  1880
# 3  Elizabeth   F    1939  1880
# 4     Minnie   F    1746  1880

# %%
allyears.tail()
# Out:
#             name sex  number  year
# 34597  Zyquarius   M       5  2009
# 34598      Zyran   M       5  2009
# 34599    Zyreion   M       5  2009
# 34600     Zyrian   M       5  2009
# 34601     Zyvion   M       5  2009

# %%
allyears_indexed=allyears.set_index(['sex','name','year']).sort_index()

# %%
allyears_indexed
# Out:
#                     number
# sex name      year
# F   Aabriella 2008       5
#     Aaden     2009       5
#     Aadhya    2007      10
#               2008       9
#               2009      18
#     Aadi      2006       5
#     Aadison   2009       6
#     Aadya     2003       5
#               2004       8
#               2005      13
#               2006      21
#               2007      16
#               2008      21
#               2009      31
#     Aadyn     2008       9
#               2009       7
#     Aafreen   2004       5
#     Aagot     1915       5
#     Aahana    2005      13
#               2006      14
#               2007      25
#               2008      32
#               2009      33
#     Aahliyah  2003       6
#               2007       6
#               2008       6
#               2009       6
#     Aahna     2007       5
#               2008       7
#               2009       7
# ...                    ...
# M   Zyshaun   2007       7
#               2008       6
#     Zyshawn   1998       9
#               1999       7
#               2000      10
#               2001      11
#               2002       6
#               2003       9
#               2004       7
#               2005       7
#               2006       5
#               2007      11
#               2008      14
#               2009       7
#     Zyshon    1998       8
#               2001       6
#               2005       5
#     Zyshonne  1998      26
#               1999      30
#               2000      17
#               2001      12
#               2002       9
#               2003       7
#     Zytavious 2002       6
#               2004       6
#               2005       5
#               2006       7
#               2007       6
#               2009       7
#     Zyvion    2009       5
#
# [1656946 rows x 1 columns]

# %%
allyears_indexed.loc['F','Mary']
# Out:
#       number
# year
# 1880    7065
# 1881    6919
# 1882    8149
# 1883    8012
# 1884    9217
# 1885    9128
# 1886    9891
# 1887    9888
# 1888   11754
# 1889   11649
# 1890   12078
# 1891   11704
# 1892   13174
# 1893   12784
# 1894   13151
# 1895   13446
# 1896   13811
# 1897   13412
# 1898   14406
# 1899   13172
# 1900   16710
# 1901   13137
# 1902   14485
# 1903   14275
# 1904   14962
# 1905   16067
# 1906   16371
# 1907   17579
# 1908   18664
# 1909   19256
# ...      ...
# 1980   11469
# 1981   11030
# 1982   10847
# 1983    9889
# 1984    9285
# 1985    9235
# 1986    8499
# 1987    8394
# 1988    8505
# 1989    8641
# 1990    8651
# 1991    8743
# 1992    8430
# 1993    8089
# 1994    7722
# 1995    7408
# 1996    6926
# 1997    6616
# 1998    6415
# 1999    6350
# 2000    6174
# 2001    5715
# 2002    5439
# 2003    4996
# 2004    4792
# 2005    4439
# 2006    4073
# 2007    3665
# 2008    3478
# 2009    3132
#
# [130 rows x 1 columns]

# %%
def plotname(sex,name):
    data=allyears_indexed.loc[sex,name]
    
    pp.plot(data.index,data.values)

# %%
plotname('F','Mary')

# %%
pp.figure(figsize=(12,2.5))

names=['Michael','John','David','Martin']

for name in names:
    plotname('M',name)
    
pp.legend(names)

# %%
pp.figure(figsize=(12,2.5))

names=['Emily','Anna','Claire','Elizabeth']

for name in names:
    plotname('F',name)
    
pp.legend(names)

# %%
pp.figure(figsize=(12,2.5))

names=['Chiara','Claire','Clare','Clara','Ciara']

for name in names:
    plotname('F',name)
    
pp.legend(names)

# %%
allyears_indexed.loc['F'].loc[names].head()
# Out:
#              number
# name   year
# Chiara 1959       9
#        1960       5
#        1962       8
#        1963       8
#        1964      12

# %%
allyears_indexed.loc['F'].loc[names].unstack(level=0).head()
# Out:
#      number
# name Chiara Ciara Claire   Clara Clare
# year
# 1880    NaN   NaN   21.0  1226.0  15.0
# 1881    NaN   NaN   23.0  1242.0  20.0
# 1882    NaN   NaN   30.0  1490.0  21.0
# 1883    NaN   NaN   38.0  1548.0  22.0
# 1884    NaN   NaN   33.0  1852.0  38.0

# %%
allyears_indexed.loc['F'].loc[names].unstack(level=0).fillna(0).head()
# Out:
#      number
# name Chiara Ciara Claire   Clara Clare
# year
# 1880    0.0   0.0   21.0  1226.0  15.0
# 1881    0.0   0.0   23.0  1242.0  20.0
# 1882    0.0   0.0   30.0  1490.0  21.0
# 1883    0.0   0.0   38.0  1548.0  22.0
# 1884    0.0   0.0   33.0  1852.0  38.0

# %%
variants=allyears_indexed.loc['F'].loc[names].unstack(level=0).fillna(0)

# %%
allyears_indexed.loc['M',:,2008].sort('number').head()
# Out:
# C:\Users\DasA0681\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                    number
# sex name     year
# M   Marquinn 2008       5
#     Orlandus 2008       5
#     Orlan    2008       5
#     Deckard  2008       5
#     Jiro     2008       5

# %%
allyears_indexed.loc['M',:,2008].sort('number',ascending=False)[:10]
# Out:
# C:\Users\DasA0681\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                       number
# sex name        year
# M   Jacob       2008   22507
#     Michael     2008   20524
#     Ethan       2008   20174
#     Joshua      2008   19133
#     Daniel      2008   18935
#     Alexander   2008   18639
#     Anthony     2008   18347
#     William     2008   18337
#     Christopher 2008   17876
#     Matthew     2008   17526

# %%
pop2008=allyears_indexed.loc['M',:,2008].sort('number',ascending=False)[:10]
# Out:
# C:\Users\DasA0681\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %%
pop2008.reset_index().drop(['sex','year','number'],axis=1).head()
# Out:
#       name
# 0    Jacob
# 1  Michael
# 2    Ethan
# 3   Joshua
# 4   Daniel

# %%
def topten(sex,year):

    simple=allyears_indexed.loc[sex,:,year].sort('number',ascending=False).reset_index()
    simple=simple.drop(['sex','year','number'],axis=1).head(10)
    
    simple.columns=[year]
    simple.index=simple.index+1
    
    return simple

# %%
topten('M',2009)
# Out:
# C:\Users\DasA0681\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()
#            2009
# 1         Jacob
# 2         Ethan
# 3       Michael
# 4     Alexander
# 5       William
# 6        Joshua
# 7        Daniel
# 8        Jayden
# 9          Noah
# 10  Christopher

# %%
def toptens(sex,year0,year1):
    years=[topten(sex,year) for year in range(year0,year1+1)]
    
    return years[0].join(years[1:])

# %%
toptens('M',2000,2009)
# Out:
# C:\Users\DasA0681\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()
#            2000         2001         2002         2003         2004  \
# 1         Jacob        Jacob        Jacob        Jacob        Jacob
# 2       Michael      Michael      Michael      Michael      Michael
# 3       Matthew      Matthew       Joshua       Joshua       Joshua
# 4        Joshua       Joshua      Matthew      Matthew      Matthew
# 5   Christopher  Christopher        Ethan       Andrew        Ethan
# 6      Nicholas     Nicholas       Andrew        Ethan       Andrew
# 7        Andrew       Andrew       Joseph       Joseph       Daniel
# 8        Joseph       Joseph  Christopher       Daniel      William
# 9        Daniel       Daniel     Nicholas  Christopher       Joseph
# 10        Tyler      William       Daniel      Anthony  Christopher
#
#            2005         2006         2007         2008         2009
# 1         Jacob        Jacob        Jacob        Jacob        Jacob
# 2       Michael      Michael      Michael      Michael        Ethan
# 3        Joshua       Joshua        Ethan        Ethan      Michael
# 4       Matthew        Ethan       Joshua       Joshua    Alexander
# 5         Ethan      Matthew       Daniel       Daniel      William
# 6        Andrew       Daniel  Christopher    Alexander       Joshua
# 7        Daniel       Andrew      Anthony      Anthony       Daniel
# 8       Anthony  Christopher      William      William       Jayden
# 9        Joseph      Anthony      Matthew  Christopher         Noah
# 10  Christopher      William       Andrew      Matthew  Christopher

# %%
toptens('F',1985,1995)
# Out:
# C:\Users\DasA0681\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()
#          1985       1986       1987       1988       1989       1990  \
# 1     Jessica    Jessica    Jessica    Jessica    Jessica    Jessica
# 2      Ashley     Ashley     Ashley     Ashley     Ashley     Ashley
# 3    Jennifer     Amanda     Amanda     Amanda   Brittany   Brittany
# 4      Amanda   Jennifer   Jennifer      Sarah     Amanda     Amanda
# 5       Sarah      Sarah      Sarah   Jennifer      Sarah   Samantha
# 6   Stephanie  Stephanie  Stephanie   Brittany   Samantha      Sarah
# 7      Nicole     Nicole   Brittany  Stephanie   Jennifer  Stephanie
# 8     Heather   Brittany     Nicole   Samantha  Stephanie   Jennifer
# 9   Elizabeth    Heather    Heather     Nicole     Lauren  Elizabeth
# 10      Megan  Elizabeth  Elizabeth  Elizabeth  Elizabeth     Lauren
#
#          1991       1992       1993       1994       1995
# 1      Ashley     Ashley    Jessica    Jessica    Jessica
# 2     Jessica    Jessica     Ashley     Ashley     Ashley
# 3    Brittany     Amanda      Sarah      Emily      Emily
# 4      Amanda   Brittany   Samantha   Samantha   Samantha
# 5    Samantha      Sarah      Emily      Sarah      Sarah
# 6       Sarah   Samantha   Brittany     Taylor     Taylor
# 7   Stephanie      Emily     Taylor   Brittany     Hannah
# 8    Jennifer  Stephanie     Amanda     Amanda   Brittany
# 9   Elizabeth  Elizabeth  Elizabeth  Elizabeth     Amanda
# 10      Emily      Megan  Stephanie      Megan  Elizabeth

# %%
toptens('F',1985,1995).stack().head()
# Out:
# C:\Users\DasA0681\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()
# 1  1985    Jessica
#    1986    Jessica
#    1987    Jessica
#    1988    Jessica
#    1989    Jessica
# dtype: object

# %%
toptens('F',1985,1995).stack().value_counts()
# Out:
# C:\Users\DasA0681\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()
# Elizabeth    11
# Jessica      11
# Sarah        11
# Ashley       11
# Amanda       11
# Brittany     10
# Stephanie     9
# Samantha      8
# Jennifer      7
# Emily         5
# Nicole        4
# Megan         3
# Taylor        3
# Heather       3
# Lauren        2
# Hannah        1
# dtype: int64

# %%
popular=toptens('F',1985,1995).stack().value_counts().index[:6]
# Out:
# C:\Users\DasA0681\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()

# %%
pp.figure(figsize=(12,2.5))

for name in popular:
    plotname('F',name)
    
pp.legend(popular)

# %%
allyears
# Out:
#             name sex  number  year
# 0           Mary   F    7065  1880
# 1           Anna   F    2604  1880
# 2           Emma   F    2003  1880
# 3      Elizabeth   F    1939  1880
# 4         Minnie   F    1746  1880
# 5       Margaret   F    1578  1880
# 6            Ida   F    1472  1880
# 7          Alice   F    1414  1880
# 8         Bertha   F    1320  1880
# 9          Sarah   F    1288  1880
# 10         Annie   F    1258  1880
# 11         Clara   F    1226  1880
# 12          Ella   F    1156  1880
# 13      Florence   F    1063  1880
# 14          Cora   F    1045  1880
# 15        Martha   F    1040  1880
# 16         Laura   F    1012  1880
# 17        Nellie   F     995  1880
# 18         Grace   F     982  1880
# 19        Carrie   F     949  1880
# 20         Maude   F     858  1880
# 21         Mabel   F     808  1880
# 22        Bessie   F     794  1880
# 23        Jennie   F     793  1880
# 24      Gertrude   F     787  1880
# 25         Julia   F     783  1880
# 26        Hattie   F     769  1880
# 27         Edith   F     768  1880
# 28        Mattie   F     704  1880
# 29          Rose   F     700  1880
# ...          ...  ..     ...   ...
# 34572  Zecharyah   M       5  2009
# 34573        Zee   M       5  2009
# 34574   Zekariah   M       5  2009
# 34575      Zekhi   M       5  2009
# 34576       Zell   M       5  2009
# 34577    Zepplin   M       5  2009
# 34578     Zequan   M       5  2009
# 34579     Zereon   M       5  2009
# 34580     Zevion   M       5  2009
# 34581       Zhen   M       5  2009
# 34582     Zhyair   M       5  2009
# 34583       Zien   M       5  2009
# 34584       Zier   M       5  2009
# 34585   Zildjian   M       5  2009
# 34586        Zim   M       5  2009
# 34587      Zimir   M       5  2009
# 34588       Ziya   M       5  2009
# 34589      Ziyun   M       5  2009
# 34590     Zlatan   M       5  2009
# 34591       Zoen   M       5  2009
# 34592     Zubayr   M       5  2009
# 34593     Zuhaib   M       5  2009
# 34594      Zykee   M       5  2009
# 34595     Zykell   M       5  2009
# 34596      Zylar   M       5  2009
# 34597  Zyquarius   M       5  2009
# 34598      Zyran   M       5  2009
# 34599    Zyreion   M       5  2009
# 34600     Zyrian   M       5  2009
# 34601     Zyvion   M       5  2009
#
# [1656946 rows x 4 columns]

# %%
allyears.groupby(['sex','name'])['number'].sum().head()
# Out:
# sex  name
# F    Aabriella     5
#      Aaden         5
#      Aadhya       37
#      Aadi          5
#      Aadison       6
# Name: number, dtype: int64

# %%
totals=allyears.groupby(['sex','name'])['number'].sum()

# %%
totals
# Out:
# sex  name
# F    Aabriella        5
#      Aaden            5
#      Aadhya          37
#      Aadi             5
#      Aadison          6
#      Aadya          115
#      Aadyn           16
#      Aafreen          5
#      Aagot            5
#      Aahana         117
#      Aahliyah        24
#      Aahna           19
#      Aaila            6
#      Aailiyah         5
#      Aailyah        117
#      Aaira            9
#      Aairah          14
#      Aaisha         133
#      Aaishah         12
#      Aaiyana          5
#      Aaiza            5
#      Aaja             5
#      Aajah           29
#      Aajaylah        20
#      Aakanksha        5
#      Aakilah         18
#      Aakira           5
#      Aakiyah          5
#      Aakriti          6
#      Aala            30
#                    ...
# M    Zymiere         35
#      Zymir          271
#      Zymire          37
#      Zyndall         14
#      Zyon          1233
#      Zyonn           10
#      Zyquan         193
#      Zyquarius       24
#      Zyquavion       11
#      Zyquavious      10
#      Zyquez          30
#      Zyran            5
#      Zyree           23
#      Zyreion          5
#      Zyrek            5
#      Zyrell          44
#      Zyren           29
#      Zyreon           7
#      Zyrese           5
#      Zyrian          10
#      Zyrion          32
#      Zyron          102
#      Zyrus           28
#      Zysean           5
#      Zyshaun         34
#      Zyshawn        103
#      Zyshon          19
#      Zyshonne       101
#      Zytavious       37
#      Zyvion           5
# Name: number, dtype: int64

# %%
def sumsq(x):
    return sum(x**2)

# %%
spikyness=allyears.groupby(['sex','name'])['number'].agg(sumsq)/totals**2

# %%
spikyness.head()
# Out:
# sex  name
# F    Aabriella    1.000000
#      Aaden        1.000000
#      Aadhya       0.368882
#      Aadi         1.000000
#      Aadison      1.000000
# Name: number, dtype: float64

# %%
spiky_common=spikyness[totals>5000].copy()
spiky_common.sort(ascending=False)
spiky_common.head(10)
# Out:
# C:\Users\DasA0681\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting
#   from ipykernel import kernelapp as app
# sex  name
# F    Miley        0.317267
#      Khloe        0.297288
# M    Shaquille    0.211682
# F    Addyson      0.169913
# M    Maddox       0.161820
# F    Kaydence     0.156580
#      Harper       0.152613
#      Addison      0.149355
# M    Braylon      0.147964
# F    Kadence      0.142596
# Name: number, dtype: float64

# %%
spiky_common.tail(10)
# Out:
# sex  name
# F    Minerva    0.009062
# M    Will       0.009020
# F    Celia      0.009012
# M    Hiram      0.008985
# F    Mollie     0.008804
#      Rosa       0.008712
# M    Ike        0.008645
# F    Delia      0.008592
#      Nora       0.008500
#      Louisa     0.008119
# Name: number, dtype: float64

# %%
pp.figure(figsize=(12,2.5))

plotname('F','Louisa')
plotname('M','Shaquille')

# %%
fads=spiky_common.head(10).index.values

# %%
pp.figure(figsize=(12,2.5))

for sex,name in fads:
    plotname(sex,name)
    
pp.legend([name for  sex,name in fads],loc='upper left')

# %%
total_recent=allyears[allyears['year']>2005].groupby(['sex','name'])['number'].sum()

# %%
spiky_common=spikyness[(totals>5000)&(total_recent<1000)].copy()
spiky_common.sort(ascending=False)
spiky_common.head(10)
# Out:
# C:\Users\DasA0681\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting
#   from ipykernel import kernelapp as app
# sex  name
# M    Shaquille    0.211682
# F    Katina       0.122173
# M    Devante      0.109426
# F    Khadijah     0.106170
# M    Tevin        0.101888
# F    Krystle      0.100335
#      Shanice      0.092730
#      Iesha        0.090717
#      Shaniqua     0.087860
#      Sheena       0.081669
# Name: number, dtype: float64

# %%
fads=spiky_common.head(10).index.values

pp.figure(figsize=(12,2.5))

for sex,name in fads:
    plotname(sex,name)
    
pp.legend([name for  sex,name in fads],loc='upper left')

# %%
totals=allyears.groupby(['sex','name'])['number'].sum()

# %%
totals_bysex=totals.unstack('sex')
totals_bysex
# Out:
# sex            F       M
# name
# Aaban        NaN    11.0
# Aabid        NaN     5.0
# Aabriella    5.0     NaN
# Aadam        NaN   126.0
# Aadan        NaN    58.0
# Aadarsh      NaN   109.0
# Aaden        5.0  2524.0
# Aadesh       NaN    10.0
# Aadhav       NaN    16.0
# Aadhya      37.0     NaN
# Aadi         5.0   390.0
# Aadil        NaN   227.0
# Aadin        NaN    67.0
# Aadison      6.0     NaN
# Aadit        NaN   134.0
# Aadith       NaN    17.0
# Aaditya      NaN   285.0
# Aadon        NaN    61.0
# Aadya      115.0     NaN
# Aadyn       16.0   205.0
# Aafreen      5.0     NaN
# Aage         NaN     7.0
# Aagot        5.0     NaN
# Aahan        NaN    58.0
# Aahana     117.0     NaN
# Aahil        NaN   133.0
# Aahliyah    24.0     NaN
# Aahna       19.0     NaN
# Aahron       NaN     5.0
# Aaidan       NaN    32.0
# ...          ...     ...
# Zyquez       NaN    30.0
# Zyra       153.0     NaN
# Zyrah       49.0     NaN
# Zyran        NaN     5.0
# Zyree       11.0    23.0
# Zyreion      NaN     5.0
# Zyrek        NaN     5.0
# Zyrell       NaN    44.0
# Zyren        NaN    29.0
# Zyreon       NaN     7.0
# Zyrese       NaN     5.0
# Zyrhiana     6.0     NaN
# Zyria      259.0     NaN
# Zyriah     164.0     NaN
# Zyrian       NaN    10.0
# Zyriana     12.0     NaN
# Zyrianna    18.0     NaN
# Zyrie        5.0     NaN
# Zyriel       5.0     NaN
# Zyrihanna   24.0     NaN
# Zyrion       NaN    32.0
# Zyron        NaN   102.0
# Zyrus        NaN    28.0
# Zysean       NaN     5.0
# Zyshaun      NaN    34.0
# Zyshawn      NaN   103.0
# Zyshon       NaN    19.0
# Zyshonne     NaN   101.0
# Zytavious    NaN    37.0
# Zyvion       NaN     5.0
#
# [87028 rows x 2 columns]

# %%
totals_both=totals_bysex.sum(axis=1)

# %%
totals_both.head(10)
# Out:
# name
# Aaban          11.0
# Aabid           5.0
# Aabriella       5.0
# Aadam         126.0
# Aadan          58.0
# Aadarsh       109.0
# Aaden        2529.0
# Aadesh         10.0
# Aadhav         16.0
# Aadhya         37.0
# dtype: float64

# %%
ratio=totals_bysex['F']/totals_bysex['M']

# %%
ratio.head()
# Out:
# name
# Aaban       NaN
# Aabid       NaN
# Aabriella   NaN
# Aadam       NaN
# Aadan       NaN
# dtype: float64

# %%
unisex=(ratio >0.25) & (ratio <4)

# %%
totals_both=totals_both[unisex]
totals_both.sort(ascending=False)
totals_both.head(5)
# Out:
# C:\Users\DasA0681\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting
#   from ipykernel import kernelapp as app
# name
# Willie    591908.0
# Jordan    433908.0
# Taylor    387894.0
# Leslie    370081.0
# Jamie     345249.0
# dtype: float64

# %%
names=totals_both.head(10).index.values

pp.figure(figsize=(12,12))

for i,name in enumerate(names):
    pp.subplot(5,2,i+1)
    
    plotname('M',name)
    plotname('F',name)
    
    pp.legend([name+' M',name + ' F'],loc='upper left')
